# %%
import pandas as pd

# %%
df = pd.read_csv('Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
df=pd.read_csv('pokemon.csv')

# %% [markdown]
# # do colume operations

# %%
print (df.head(n=10))
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
## cleaning values and annotation

# %%
df.columns = df.columns.str.upper().str.replace('_','')

# %%
df.head()
# Out:
#    #                   NAME TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df[df['LEGENDARY']==True].head(5)
# Out:
#        #                 NAME    TYPE 1    TYPE 2  TOTAL   HP  ATTACK  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
#
#      DEFENSE  SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# 158       90      125       85     90           1       True
# 162       90      154       90    130           1       True
# 163      100      154      100    130           1       True

# %%
df = df.set_index('NAME')

# %%
df.index = df.index.str.replace("..*(?=mega)","")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1752\3270781262.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.index = df.index.str.replace("..*(?=mega)","")

# %%
df.head(10)
# Out:
#                            # TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  \
# NAME
# Bulbasaur                  1  Grass  Poison    318  45      49       49
# Ivysaur                    2  Grass  Poison    405  60      62       63
# Venusaur                   3  Grass  Poison    525  80      82       83
# VenusaurMega Venusaur      3  Grass  Poison    625  80     100      123
# Charmander                 4   Fire     NaN    309  39      52       43
# Charmeleon                 5   Fire     NaN    405  58      64       58
# Charizard                  6   Fire  Flying    534  78      84       78
# CharizardMega Charizard X  6   Fire  Dragon    634  78     130      111
# CharizardMega Charizard Y  6   Fire  Flying    634  78     104       78
# Squirtle                   7  Water     NaN    314  44      48       65
#
#                            SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
# Bulbasaur                       65       65     45           1      False
# ...

# %%
df=df.drop(['#'],axis=1)

# %%
print('The columns of the dataset are:',df.columns)
# Out:
# The columns of the dataset are: Index(['TYPE 1', 'TYPE 2', 'TOTAL', 'HP', 'ATTACK', 'DEFENSE', 'SP. ATK',
#        'SP. DEF', 'SPEED', 'GENERATION', 'LEGENDARY'],
#       dtype='object')

# %%
print('The shape of the dataframe is:',df.shape)
# Out:
# The shape of the dataframe is: (800, 11)

# %%
print(df[((df['TYPE 1']=='water')|(df['TYPE 1']=='dragon'))&((df['TYPE 2']=='dragon')|(df['TYPE 2']=='FIre'))].head(3))
# Out:
# Empty DataFrame
# Columns: [TYPE 1, TYPE 2, TOTAL, HP, ATTACK, DEFENSE, SP. ATK, SP. DEF, SPEED, GENERATION, LEGENDARY]
# Index: []

# %%
print("MAX HP:",df['HP'].argmax())
# Out:
# MAX HP: 261

# %%
print("Max DEFENCE:",(df['DEFENSE']).idxmax())
# Out:
# Max DEFENCE: SteelixMega Steelix

# %%
df.sort_values('TOTAL',ascending=False).head(3)
# Out:
#                         TYPE 1    TYPE 2  TOTAL   HP  ATTACK  DEFENSE  \
# NAME
# RayquazaMega Rayquaza   Dragon    Flying    780  105     180      100
# MewtwoMega Mewtwo Y    Psychic       NaN    780  106     150       70
# MewtwoMega Mewtwo X    Psychic  Fighting    780  106     190      100
#
#                        SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
# RayquazaMega Rayquaza      180      100    115           3       True
# MewtwoMega Mewtwo Y        194      120    140           1       True
# MewtwoMega Mewtwo X        154      100    130           1       True

# %%
df2=df.drop(['GENERATION','TOTAL'],axis=1)

# %%
sns.boxplot(daata=df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sns.boxplot(daata=df2)
#
# NameError: name 'sns' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.rand(5,5)
plt.imshow(data,cmap='hot') 
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
data_cleaned = df.dropna()
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 414 entries, Bulbasaur to Volcanion
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TYPE 1      414 non-null    object
#  1   TYPE 2      414 non-null    object
#  2   TOTAL       414 non-null    int64
#  3   HP          414 non-null    int64
#  4   ATTACK      414 non-null    int64
#  5   DEFENSE     414 non-null    int64
#  6   SP. ATK     414 non-null    int64
#  7   SP. DEF     414 non-null    int64
#  8   SPEED       414 non-null    int64
#  9   GENERATION  414 non-null    int64
#  10  LEGENDARY   414 non-null    bool
# dtypes: bool(1), int64(8), object(2)
# memory usage: 36.0+ KB

# %%
data_filled_mean = df.fillna(df.mean())
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 414 entries, Bulbasaur to Volcanion
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TYPE 1      414 non-null    object
#  1   TYPE 2      414 non-null    object
#  2   TOTAL       414 non-null    int64
#  3   HP          414 non-null    int64
#  4   ATTACK      414 non-null    int64
#  5   DEFENSE     414 non-null    int64
#  6   SP. ATK     414 non-null    int64
#  7   SP. DEF     414 non-null    int64
#  8   SPEED       414 non-null    int64
#  9   GENERATION  414 non-null    int64
#  10  LEGENDARY   414 non-null    bool
# dtypes: bool(1), int64(8), object(2)
# memory usage: 36.0+ KB
# ...

# %%
data_filled_median =df.fillna(df.median())
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 414 entries, Bulbasaur to Volcanion
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TYPE 1      414 non-null    object
#  1   TYPE 2      414 non-null    object
#  2   TOTAL       414 non-null    int64
#  3   HP          414 non-null    int64
#  4   ATTACK      414 non-null    int64
#  5   DEFENSE     414 non-null    int64
#  6   SP. ATK     414 non-null    int64
#  7   SP. DEF     414 non-null    int64
#  8   SPEED       414 non-null    int64
#  9   GENERATION  414 non-null    int64
#  10  LEGENDARY   414 non-null    bool
# dtypes: bool(1), int64(8), object(2)
# memory usage: 36.0+ KB
# ...

# %%
data_cleaned =df.drop_duplicates()

# %%
data2 =['SPEED','HP']
data_cleaned=df.drop(columns=data2)
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TYPE 1      800 non-null    object
#  1   TYPE 2      414 non-null    object
#  2   TOTAL       800 non-null    int64
#  3   ATTACK      800 non-null    int64
#  4   DEFENSE     800 non-null    int64
#  5   SP. ATK     800 non-null    int64
#  6   SP. DEF     800 non-null    int64
#  7   GENERATION  800 non-null    int64
#  8   LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(6), object(2)
# memory usage: 57.0+ KB

# %%
import numpy as np
df
df['ATTACK']= np.log(df['HP'])
df
# Out:
#                         TYPE 1  TYPE 2  TOTAL  HP    ATTACK  DEFENSE  SP. ATK  \
# NAME
# Bulbasaur                Grass  Poison    318  45  3.806662       49       65
# Ivysaur                  Grass  Poison    405  60  4.094345       63       80
# Venusaur                 Grass  Poison    525  80  4.382027       83      100
# VenusaurMega Venusaur    Grass  Poison    625  80  4.382027      123      122
# Charmander                Fire     NaN    309  39  3.663562       43       60
# ...                        ...     ...    ...  ..       ...      ...      ...
# Diancie                   Rock   Fairy    600  50  3.912023      150      100
# DiancieMega Diancie       Rock   Fairy    700  50  3.912023      110      160
# HoopaHoopa Confined    Psychic   Ghost    600  80  4.382027       60      150
# HoopaHoopa Unbound     Psychic    Dark    680  80  4.382027       60      170
# Volcanion                 Fire   Water    600  80  4.382027      120      130
#
# ...

# %%
data_encoded=pd.get_dummies(df,columns=['ATTACK'])
df
# Out:
#                         TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Bulbasaur                Grass  Poison    318  45      49       49       65
# Ivysaur                  Grass  Poison    405  60      62       63       80
# Venusaur                 Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur    Grass  Poison    625  80     100      123      122
# Charmander                Fire     NaN    309  39      52       43       60
# ...                        ...     ...    ...  ..     ...      ...      ...
# Diancie                   Rock   Fairy    600  50     100      150      100
# DiancieMega Diancie       Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined    Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound     Psychic    Dark    680  80     160       60      170
# Volcanion                 Fire   Water    600  80     110      120      130
#
# ...
